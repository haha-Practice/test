# %% [markdown]
# ## Day_11

# %%
print("String")
# anything you close inside a double or a single quotes are a string.
# for multi line string we need to go with a triple single or double quotes.
# a string is a sequence or array of textual data.
# string are used when we work with a unicode characters

a = ("Assalam O Alakom")
b = ('''hi my name is ahmad
and i learing Python.
and i am the student of a GCP.''')
c = ("""hi my name is ahmad
and i learing Python.
and i am the student of a GCP.""")

print(a)
print(b)
print(c)

# %%
print("Accessing the character of the string")
# the string is like an array and we can access the character of an array by the using the square brackets after the variabel name and put the index of the character you access from the string.
# and the indexing of the character in a string is start from 0(Zero).

# %%
print("Accessing the character of a string by indexing")
a = "hi my name is ahmad"
character = a[8]
print(character)
# Out:
# Accesing the character of a string by indexing
# m

# %%
print("Accessing the character of the string by loop")

name = "code inside the vscode"
for i in name:
    print(i)

# here the "i" is use to make the supposition in the name or what ever you want to access by  for loop
# in above the "for" are key word for loop which we use when we calling or using loop
# and the "in" are use as the Membership operator which execute the data inside the specific data or set.

# %% [markdown]
# ## Day_12

# %%
print("String Slicing")
# the counting of the index of the string or list what ever you want is start from the 0.
# for slicing we use the square brackets[] before we specifi the statring index and the end index of slice data.
# the string slicing are used to slice a data by specifing the starting index and the ending index for slicing data.
# by default the starting index is set to the [0:x] and the ending index is set to len(slicing_data) [x:len(list)]
# during slicing the python eleminate the last index value and not include it in a slice data.
# the negative slicing is also a part of the slicing where we start the indexing from the last entery and go backward as far as we need.
# Out:
# String Slicing

# %%
x = "namekhan"
print(x[-7:-1])#x[staring_index:ending_index] but ignore the last index character or
# Out:
# amekha

# %%
nm = "abcdef"
print(nm[-4:-2])
# Out:
# cd

# %%
name = "codewithharry"
print(len(name))
print(name[:5])#[0:5]
print(name[5:])#[5:len(name)]
print(name[:-1])#[-len(name):-1]
print(name[0:])# [0:len(name)]
# Out:
# 13
# codew
# ithharry
# codewithharr
# codewithharry

# %% [markdown]
# ## Day_13

# %%
print("String Methods")
#In Python, a method is a function that is associated with an object or a class. It's a fundamental concept in object-oriented programming (OOP), allowing objects to perform actions and interact with their own data (attributes).

# this all mothods use to generate the new string and then apply all functions on it and dont change the existing string
#
#

v = "HELLO"
w = "my name is Ahmad"
x = "abcd0fghijklmnO0pqrStuv0wxy\nZ!!!"
y = "abcde"
z = "      "

print(len(x)) # find the length of the string
print(x.upper()) # convert to upper case characters
print(v.swapcase()) # convert to upper case characters to lower and vice versa
print(x.lower()) # convert to lower case characters
print(x.strip("!")) # remove the starting and last entity in a string.Removes leading and trailing characters: strip() targets characters at the very beginning and very end of the string. It does not affect characters in the middle of the string. .Default behavior (whitespace removal): If called without any arguments, strip() removes all whitespace characters (spaces, tabs \t, newlines \n, carriage returns \r) from both ends of the string.
print(x.replace("0","Zero")) # replace the specify character or data (word , sentence) in side the string with specific data.
print(x.split("0")) # the split methods help to divide the string into list[] by the behave of occurense of specific character you specify to break or divide the string in specific points like white spaces(" ") , commas(,) etc...
print(w.title()) # convert the fisrt letter case to upper.
print(x.capitalize()) # capitalize the first letter of the string.they turn the first letter into capital but the rest of the string words are be the a lower case
print(x.center(50)) # the center methods help to center the sting into the consol according to the peramenter you give to him.Here "50" is used to tell  python to create a 50/2 single spaces in both sides if you declare the 100 spces they give 50 to each side i mean left and right.
print(x.count("0")) # tell us how much time the particualr character are exit in the string.or repeat inside the string.
print(y.startswith("d",3,)) # tell us the string are it's start with the specific character or not.We also specify the region iside the string is the specific valuea or character are lie inside the string from position of dash to dash like x.startswith("!!",5,) like x.startswith("character_specific",start_searching_point,end_searching_point).
print(y.endswith("de",0,)) # tell us the string are it's end with the specific character or not.We also specify the region iside the string is the specific valuea re character are lie inside the string from position of dash to dash like x.endswith("!!",5,) like x.endswith("character_specific",start_searching_point,end_searching_point)if you add the last point the python not check the last entery but not the second last character and show the result False.
print(x.find("m")) #the methods help to find the specific character or word inside the string and give us answer in the form of the index of the first occurence of specific character that we find.and if the specific character is not find they give -1.
print(x.index("k")) # this methos is also like a find but if the value of specify character of word are not find it give us error not -1.
print(x.isalnum()) # the method insure is the entire string consist only a-z,A-Z,0-9.If any another character or symbol are find inside the string nother then this three types do they give False other wise give true if all entites are alpabets or numbers.In Python, "alphanumeric" refers to characters that are either letters of the alphabet (a-z, A-Z) or digits (0-9). It specifically excludes special characters (like !, @, #, $, %, etc.) and whitespace characters (like spaces, tabs, newlines)
print(x.isalpha()) # this insure only the alphabetics(a-z,A-Z) enteries and check only it if no other entity gives True other wise False if find other then this character or symbols.
print(x.islower()) # it insure all the character are in the lower case if all the entities are in a lower case it print the True other wise print False
print(v.isupper()) # it insure all the character are in the upper case if all the entities are in a upper case it print the True other wise print False
print(x.isprintable()) # insure all the entities in the string are printabel no any escape sequense are not use in it if not and escap sequence print True other wise if find \n , \t or other print False. Not space in clude the default space the |t or any other are escap sequence character it are not printabel but the keyboard space are not include in it.
print(z.isspace()) # this method give us True if the string contain only and only white spacess.other waise it give False.Like a = "       "
print(w.istitle()) # give True if the the every word of the string start with a capital word.If any other entity other then first are in upper case it give False because it checks the all first latter of word are capitalize.
# Out:
# String Methods
# hello
# My Name Is Ahmad

# %% [markdown]
# ## Day_14

# %%
print("If Else conditional statement")
# the if else statement are use to make a plane or conditions for specific function if the specific work done do this or not then do this and same like that we use the else if conditional staement
# the if else condition have some concepts the first one is the bloks when we spedify cindition so we need to write some action accossiated with that condition so we need indentation to make a block of code inside a python file.
# Out:
# If Else conditional statement

# %%
# this if else conditional statment are use only ones when you have only two possibilities and to option rather then a tons of possibilites and options.

age =int(input("Enter Your Age: "))

if age >= 18:# if the if statement satisfide and the condition are met so they perform the specific action that is assign to it inside his block if not they go to else and perform the action inside it's block.
    print("You Can Drive")
else:
    print("You Can't Drive.")
# Out:
# You Can't Drive.

# %%
# while the if elif else contional statment are use when we have many possibilites and many option to select and go with.

marks = int(input("Enter your marks :"))
if marks >= 88:
    grade = "A+"
elif marks >= 77:
    grade = "A"
elif marks >= 66:
    grade = "B"
elif marks >= 55:
    grade = "C"
elif marks >= 44:
    grade = "Fail"

print(f"You are in grade {grade}")

# %%
num = int(input("Enter any number : "))
type(num)

if (num < 0):
    print(f"The {num} is Negative number.")
elif (num == 0):
    print(f"The {num} is equal to Zero.")
elif (num > 0):
    print(f"The {num} is Positive number.")
else:
    print("Enter a Valid Integer")

# %% [markdown]
# 0    - 1000 science , math , bio , phy ,eng ,cs ,quantam p
# 1000 - 2000 arts  eng , urdu , ps, islam , mq
# 2000 - 3000 Religon islam , jew , christ , hindu , sikh

# %% [markdown]
# ## Employ Id Generater

# %%
import random

str = input("Enter Your Name : ")

# generate 4 digit ID from 0000 to 3000
e_id = random.randint(0, 3000)
raw_id = f"{e_id}"
emp_id =  raw_id.zfill(4)


employee_name = str.title()

print(f"Employee ID for {employee_name} is :", emp_id)

with open ("Employee_Data_base.txt","a") as file:
    file.write(f"{employee_name},{emp_id}\n")
# Out:
# Employee ID for Muhammad Ahmad is : 0507

# %%
emp_name = input("Enter Your Name: ").title()
emp_id = int(input("Enter your ID number: "))

DB_FILE = "employees.txt"

def id_finder(emp_id):
    try:
        with open(DB_FILE, "r") as file:
            for line in file:
                if line.startswith(str(emp_id) + ","):
                    return True
    except FileNotFoundError:
        return False
    return False


if id_finder(emp_id):

    if 0 <= emp_id < 1000:
        if 0 <= emp_id < 200:
            dept = "Biology"
        elif 200 <= emp_id < 400:
            dept = "Physics"
        elif 400 <= emp_id < 600:
            dept = "Engineering"
        elif 600 <= emp_id < 800:
            dept = "Computer Science"
        elif 800 <= emp_id < 1000:
            dept = "Quantum Physics"

    elif 1000 <= emp_id < 2000:
        if 1000 <= emp_id < 1200:
            dept = "English"
        elif 1200 <= emp_id < 1400:
            dept = "Urdu"
        elif 1400 <= emp_id < 1600:
            dept = "PAK-Study"
        elif 1600 <= emp_id < 1800:
            dept = "Islamiate"
        elif 1800 <= emp_id < 2000:
            dept = "Mutalia Quran"

    elif 2000 <= emp_id < 3000:
        if 2000 <= emp_id < 2200:
            dept = "Islamic"
        elif 2200 <= emp_id < 2400:
            dept = "Christianic"
        elif 2400 <= emp_id < 2600:
            dept = "Hinduic"
        elif 2600 <= emp_id < 2800:
            dept = "Jewish"
        elif 2800 <= emp_id < 3000:
            dept = "Sikh"

    else:
        print("❌ Please enter a valid ID number!")
        exit()

else:
    print(f"❌ The Employee ID {emp_id} of {emp_name} does not exist in database.")
    exit()


print(f"{emp_name}, you are in {dept} Department")
print(f"Assalam O Alaikum {emp_name}, have a Good day!")
print("MAY ALLAH BLESS YOU! 🤲")

with open(DB_FILE, "a") as file:
    file.write(f"{emp_id}, {emp_name}, {dept}\n")

print("\n✅ Data saved successfully in employees.txt!")

# %% [markdown]
# ## and Classifier

# %%
str = input("Enter Your Name: ")
emp_name = str.title()
emp_id = int(input("Enter your ID number: "))


def id_finder(emp_id):
        with open ("Employee_Data_base.txt" , "r") as file:
            for line in file:
                    if line.startswith({emp_id} , ","):
                        True
                    else :
                        return False


if id_finder(emp_id)==True:
    if (0<id<1000):
        if 0<id<1000:
                    dept = "Mathematics"
        elif (0<id<200):
                        dept = "Biology"
        elif (200<id<400):
                        dept = "Physics"
        elif (400<id<600):
                        dept = "Engineering"
        elif (600<id<800):
                        dept = "Computer Science"
        elif (800<id<1000):
                        dept = "Quantum Physics"

    elif (1000<id<2000):
        if (1000<id<1200):
                            dept = "English"
        elif (1200<id<1400):
                            dept = "Urdu"
        elif (1400<id<1600):
                            dept = "PAK-Study"
        elif (1600<id<1800):
                            dept = "Islamiate"
        elif (1800<id<2000):
                            dept = "Mutalia Quran "

    elif (2000<id<3000):
        if (2000<id<2200):
                        dept = "Islamic"
        elif (2200<id<2400):
                            dept = "Cristianic"
        elif (2400<id<2600):
                            dept =  "Hinduic"
        elif (2600<id<2800):
                            dept =  "Jewisic"
        elif (2800<id<3000):
                            dept = "Shiks"
    else:
        print("Please Enter a valid name and Id number")
else:
     print(f"The Employee ID of {emp_name} , {emp_id} not Exist.")

print(f"{emp_name} you are in {dept} Department")
print(f"Aslam O Alakom {emp_name}, \n\thave a Good day!")
print("MAY ALLAH BLESS YOU!")


with open("Day_14_employees.txt", "a") as file:
    file.write(f"=========={emp_id}========== \nName: {emp_name} \nID: {emp_id} \nDepartment: {dept}\n")

print("\n✅ Data saved successfully in employees.txt!")

# %% [markdown]
# ## Day_15

# %%
import time

now = time.localtime()

print("year is :" , now.tm_year)
print("month is :" , now.tm_mon)
print("day is :" , now.tm_mday)
print("hour is :" , now.tm_hour)
# Out:
# year is : 2066
# month is : 9
# day is : 29
# hour is : 9

# %%
import time
def c_t():
    hour = time.localtime().tm_hour
    current_time =  time.strftime("%H:%M:%S")

    if (5<hour<8):
        print(f"It's Early Morning and the time is {current_time}")
    elif (8<hour<12):
        print(f"It's Morning and the time is {current_time}")
    elif (12<hour<14):
        print(f"It's Noon and the time is {current_time}")
    elif (14<hour<17):
        print(f"It's AfterNoon and the time is {current_time}")
    elif (17<hour<20):
        print(f"It's Evening and the time is {current_time}")
    elif (20<hour<24):
        print(f"It's Night and the time is {current_time}")

print(type(hour))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 19
#      16     elif (20<hour<24):
#      17         print(f"It's Night and the time is {current_time}")
# ---> 19 print(type(hour))
#
# NameError: name 'hour' is not defined

# %%
c_t()

# %%
import time
a = time.ctime()# show the current time in understandinf formate the C reffer s to Calendar time
print(a)
